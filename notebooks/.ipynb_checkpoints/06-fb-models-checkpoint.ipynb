# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import ElasticNet, LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (
    OrdinalEncoder,
    OneHotEncoder, 
    PolynomialFeatures,
    PowerTransformer,
    RobustScaler,
    StandardScaler,
    QuantileTransformer,
)

from src.config import CLEAN_DATA
from src.models import train_and_validate_regression_model, organize_results, grid_search_cv_regressor
from src.plots import plot_coefs, plot_residuals, plot_compare_models_metrics, plot_residuals_estimator
from src.utils import dataframe_coefs

# %%
df = pd.read_parquet(CLEAN_DATA)

df.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2        1206         595         2.0804              226700        NEAR BAY
# 3         697         264         2.1250              140000        NEAR BAY
# 4         990         419         1.9911              158700        NEAR BAY
#
#   median_income_cat  population_per_household  rooms_per_household  \
# 0                6+                  2.555556             6.984127
# 1                6+                  2.109842             6.238137
# 2               1.5                  2.026891             4.294117
# 3               1.5                  2.640152             4.242424
# 4               1.5                  2.362768             5.343676
#
#    bedrooms_per_household  bedrooms_per_room
# 0                1.023810           0.146591
# 1                0.971880           0.155797
# 2                1.117647           0.260274
# 3                1.071970           0.252679
# 4                1.085919           0.203216

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17540 entries, 0 to 17539
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   longitude                 17540 non-null  float32
#  1   latitude                  17540 non-null  float32
#  2   housing_median_age        17540 non-null  int8
#  3   total_rooms               17540 non-null  int16
#  4   total_bedrooms            17540 non-null  int16
#  5   population                17540 non-null  int16
#  6   households                17540 non-null  int16
#  7   median_income             17540 non-null  float32
#  8   median_house_value        17540 non-null  int32
#  9   ocean_proximity           17540 non-null  category
#  10  median_income_cat         17540 non-null  category
#  11  population_per_household  17540 non-null  float32
#  12  rooms_per_household       17540 non-null  float32
#  13  bedrooms_per_household    17540 non-null  float32
#  14  bedrooms_per_room         17540 non-null  float32
# dtypes: category(2), float32(7), int16(4), int32(1), int8(1)
# memory usage: 737.1 KB

# %% [markdown]
# ### separando colunas para diferentes processamentos

# %%
# coluna do target
column_target = ['median_house_value']

# colunas categóricas ordinárias - ordinal encoder
columns_cat_ordinal = ['median_income_cat']

#colunas categóricas nominais - one hot encoder
columns_cat_nominal = ['ocean_proximity']

# colunas numéricas para robust scaler
columns_robust_scaler = df.columns.difference(column_target + columns_cat_ordinal + columns_cat_nominal)

# %%
pipe_poly = Pipeline(steps=[
    ('robust_scaler', RobustScaler()),
    ('poly', PolynomialFeatures(degree=1, include_bias=False))
])

prep = ColumnTransformer(
    transformers=[
        ('ordinal_encoder', OrdinalEncoder(categories='auto'), columns_cat_ordinal),
        ('one_hot_encoder', OneHotEncoder(drop='first'), columns_cat_nominal),
        ('robust_scaler_poly', pipe_poly, columns_robust_scaler),
    ],
)

# %%
X = df.drop(columns=column_target)
y = df[column_target]

X.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income ocean_proximity median_income_cat  \
# 0         322         126         8.3252        NEAR BAY                6+
# 1        2401        1138         8.3014        NEAR BAY                6+
# 2        1206         595         2.0804        NEAR BAY               1.5
# 3         697         264         2.1250        NEAR BAY               1.5
# 4         990         419         1.9911        NEAR BAY               1.5
#
#    population_per_household  rooms_per_household  bedrooms_per_household  \
# 0                  2.555556             6.984127                1.023810
# 1                  2.109842             6.238137                0.971880
# 2                  2.026891             4.294117                1.117647
# 3                  2.640152             4.242424                1.071970
# 4                  2.362768             5.343676                1.085919
#
#    bedrooms_per_room
# 0           0.146591
# 1           0.155797
# 2           0.260274
# 3           0.252679
# 4           0.203216

# %%
y.head()
# Out:
#    median_house_value
# 0              452600
# 1              358500
# 2              226700
# 3              140000
# 4              158700

# %% [markdown]
# ### Testando diferentes reg para o transformers

# %%
param_grid = {
    'regressor__preprocessor__robust_scaler_poly__poly__degree': [1, 2, 3],
}

# %%
grid_search = grid_search_cv_regressor(
    regressor=LinearRegression(),
    param_grid=param_grid,
    preprocessor=prep,
    target_transformer=QuantileTransformer(output_distribution='normal'),
)

grid_search
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot_encoder',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pipeline(steps=[('robust_sc...
#        'population', 'population_per_household', 'rooms_per_household',
#        'total_bedrooms', 'total_rooms'],
#       dtype='object'))])),
#                                                                             ('reg',
#                                                                              LinearRegression())]),
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.fit(X,y)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot_encoder',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pipeline(steps=[('robust_sc...
#        'population', 'population_per_household', 'rooms_per_household',
#        'total_bedrooms', 'total_rooms'],
#       dtype='object'))])),
#                                                                             ('reg',
#                                                                              LinearRegression())]),
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.best_params_
# Out:
# {'regressor__preprocessor__robust_scaler_poly__poly__degree': 2}

# %%
grid_search.best_score_
# Out:
# np.float64(-51358.62177559697)

# %% [markdown]
# ### Verificando coefs

# %%
coefs = dataframe_coefs(
    grid_search.best_estimator_.regressor_['reg'].coef_,
    grid_search.best_estimator_.regressor_['preprocessor'].get_feature_names_out(),
)

coefs = coefs[~coefs['coefficients'].between(-5_000, 5_000)] # filtrar para os coefs com maiores índices

plot_coefs(coefs)
# Out:
# <Axes: title={'center': 'coefs'}, xlabel='coefficients'>

# %% [markdown]
# ### Testando modelos básicos com Dummy Regressor e Grid Search

# %%
regressors = {
    'DummyRegressor': {
        'preprocessor': None,
        'regressor': DummyRegressor(),
        'target_transformer': None
    },
    'LinearRegression': {
        'preprocessor': prep,
        'regressor': LinearRegression(),
        'target_transformer': None
    },
    'LinearRegression_target': {
        'preprocessor': prep,
        'regressor': LinearRegression(),
        'target_transformer': QuantileTransformer(output_distribution='normal')
    },
    'LinearRegression__grid_search': {
        'preprocessor': grid_search.best_estimator_.regressor_['preprocessor'],
        'regressor': grid_search.best_estimator_.regressor_['reg'],
        'target_transformer': grid_search.best_estimator_.transformer_
    },
}

# %%
results = {
    name: train_and_validate_regression_model(X, y, **reg)
    for name, reg in regressors.items()
}

df_results = organize_results(results)
df_results
# Out:
#                             model  fit_time score_time   test_r2  \
# 0                  DummyRegressor  0.004404   0.003203 -0.000023
# 1                  DummyRegressor   0.00265   0.002598 -0.000097
# 2                  DummyRegressor  0.002652   0.003193 -0.000306
# 3                  DummyRegressor  0.002427   0.002086 -0.000177
# 4                  DummyRegressor  0.001646    0.00232 -0.000351
# 5                LinearRegression   0.02722   0.004823  0.675141
# 6                LinearRegression  0.016878   0.003605  0.657973
# 7                LinearRegression  0.015344    0.00319  0.677336
# 8                LinearRegression  0.014593   0.003044  0.668384
# 9                LinearRegression  0.014408   0.002962  0.669717
# 10        LinearRegression_target   0.01776   0.003611  0.682774
# 11        LinearRegression_target  0.018135   0.003349    0.6707
# 12        LinearRegression_target  0.017606   0.003242  0.680867
# 13        LinearRegression_target  0.017515   0.003228  0.679679
# 14        LinearRegression_target  0.017309   0.003204  0.680052
# 15  LinearRegression__grid_search  0.055859   0.004469  0.718437
# 16  LinearRegression__grid_search  0.052844   0.004464  0.698079
# 17  LinearRegression__grid_search  0.053321   0.004435  0.717987
# 18  LinearRegression__grid_search  0.052291   0.004301  0.713998
# 19  LinearRegression__grid_search  0.049339   0.004281  0.719244
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -75344.044088                    -94652.640506     0.007607
# 1                 -77815.127629                    -97815.256263     0.005248
# 2                 -76136.496188                    -94937.860727     0.005845
# 3                 -77950.972211                    -97233.485191     0.004513
# 4                 -76205.284096                    -95116.688912     0.003966
# 5                 -39557.794793                    -53948.002416     0.032043
# 6                 -41974.513255                     -57202.61032     0.020483
# 7                 -40330.004528                     -53919.80884     0.018534
# 8                 -41296.628579                    -55988.011805     0.017637
# 9                 -40331.285373                    -54654.198752      0.01737
# 10                -37945.991801                    -53310.408334     0.021371
# 11                -39577.116232                    -56128.268406     0.021484
# 12                -38660.986513                    -53623.957599     0.020848
# 13                -38951.681581                    -55026.252957     0.020743
# 14                -37962.173667                    -53792.293373     0.020513
# 15                -35149.378486                    -50224.460869     0.060328
# 16                -37466.813168                    -53744.279608     0.057308
# 17                -35890.019025                    -50408.962626     0.057756
# 18                -36368.336052                    -51995.053058     0.056592
# 19                -35543.373204                    -50390.074344      0.05362

# %%
plot_compare_models_metrics(df_results)

# %% [markdown]
# maior rendimento, porém com maior custo do tempo

# %% [markdown]
# ### Verificando resíduos do best estimator

# %%
plot_residuals_estimator(grid_search.best_estimator_, X, y)
